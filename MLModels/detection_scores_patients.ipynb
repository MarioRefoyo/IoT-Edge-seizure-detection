# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
knn_data = pd.read_csv('results_detection\\{}_1channels.csv'.format('knn'), delimiter=',')
rnf_data = pd.read_csv('results_detection\\{}_1channels.csv'.format('rnf'), delimiter=',')
svm_data = pd.read_csv('results_detection\\{}_1channels.csv'.format('svm_rbf'), delimiter=',')
all_data = pd.concat([knn_data, rnf_data, svm_data]).reset_index(drop=True)

# %%
all_data
# Out:
#    patient    model                                    hyperparameters  \
# 0    chb01      knn  {'clf__n_neighbors': 1, 'clf__p': 2, 'clf__wei...
# 1    chb02      knn  {'clf__n_neighbors': 1, 'clf__p': 2, 'clf__wei...
# 2    chb03      knn  {'clf__n_neighbors': 4, 'clf__p': 1, 'clf__wei...
# 3    chb04      knn  {'clf__n_neighbors': 1, 'clf__p': 1, 'clf__wei...
# 4    chb05      knn  {'clf__n_neighbors': 1, 'clf__p': 2, 'clf__wei...
# ..     ...      ...                                                ...
# 61   chb19  svm_rbf  {'clf__C': 1000, 'clf__gamma': 0.01, 'clf__ker...
# 62   chb20  svm_rbf  {'clf__C': 1000, 'clf__gamma': 0.01, 'clf__ker...
# 63   chb21  svm_rbf  {'clf__C': 1000, 'clf__gamma': 0.1, 'clf__kern...
# 64   chb22  svm_rbf  {'clf__C': 10, 'clf__gamma': 0.1, 'clf__kernel...
# 65   chb23  svm_rbf  {'clf__C': 100, 'clf__gamma': 0.01, 'clf__kern...
#
#     sensitivity  specificity   roc_auc  precision  accuracy
# 0      0.860465     1.000000  0.930233   1.000000  0.995951
# 1      1.000000     0.998609  0.999305   0.888889  0.998624
# 2      0.871795     0.997915  0.934855   0.918919  0.994587
# 3      0.540541     0.997977  0.769259   0.740741  0.993139
# 4      0.890909     0.999305  0.945107   0.980000  0.995315
# ..          ...          ...       ...        ...       ...
# 61     0.739130     0.996293  0.867712   0.809524  0.990926
# 62     0.678571     0.998610  0.838591   0.904762  0.992502
# 63     0.421053     0.997915  0.709484   0.727273  0.990398
# 64     0.950000     1.000000  0.975000   1.000000  0.999090
# 65     0.634146     0.998124  0.816135   0.812500  0.993517
#
# [66 rows x 8 columns]

# %%
sns.set(style="white", font_scale=1.5)
g = sns.catplot(x="patient", y="roc_auc", hue="model", data=all_data, height = 10, aspect=2, kind="bar", palette="muted")
g.fig.suptitle('Roc area of every patient', fontsize=38)
g.set(ylim=(0.49, 1))

# %%
sns.set(style="white", font_scale=1.5)
g = sns.catplot(x="patient", y="sensitivity", hue="model", data=all_data, height = 10, aspect=2, kind="bar", palette="muted")
g.fig.suptitle('Sensitivity of every patient', fontsize=30)
# Out:
# Text(0.5, 0.98, 'Sensitivity of every patient')

# %%
sns.set(style="white", font_scale=1.5)
g = sns.catplot(x="patient", y="specificity", hue="model", data=all_data, height = 10, aspect=2, kind="bar", palette="muted")
g.despine(left=True)
g.fig.suptitle('Specificity of every patient', fontsize=30)
# Out:
# Text(0.5, 0.98, 'Specificity of every patient')

# %%
sns.set(style="white", font_scale=1.5)
g = sns.catplot(x="patient", y="precision", hue="model", data=all_data, height = 10, aspect=2, kind="bar", palette="muted")
g.despine(left=True)
g.fig.suptitle('Precision of every patient', fontsize=30)
# Out:
# Text(0.5, 0.98, 'Precision of every patient')
